# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
# Responses list
responses = [
    "To target new problems",
    "economic growth",
    "development",
    "To further improve technology",
    "to keep our (leading) position",
    "For process, progress and inspiration.",
    "To adapt to changing environments, digital, socio-cultural, political",
    "In order to ensure long-term competitiveness and creat new value",
    "We need innovation to create new solutions",
    "To provide good solutions to existing problems",
    "Creative",
    "To evolve as a society, but also economically",
    "- to solve problems that still persist - to improve current products and systems - to cater to new problems",
    "Development",
    "Economy growth",
    "To drive profits :0",
    "Innovation is the source of long term growth by improving productivity and the overall quaility of life",
    "Innovation is essenti for wealth, prosperity and sustainability.",
    "In order to improve businesses and technology and stay competitive as well as adjusting two new world settings, innovation is mandatory",
    "To advance ourselves, to explore new unknown areas, to find new solutions to problems.",
    "Shumpeterian creative destruction! So we stop doing a thing the stupid old way and start doing it in a slightly less stupid new way",
    "Generally to achieve efficiency",
    "To keep economy going while working on Solveig upcoming problems",
    "To improve our quality of life (as a society)",
    "Because we live in a capitalist society",
    "Mankind has developed many things - good and bad. Thus, innovation is needed to push the good for a better and stable future, while overthinking the bad and perhaps leaving it behind.",
    "Improving life",
    "Progress and survival",
    "For further growth and development of economies",
    "to create new markets",
    "Mostly we need it for economic growth and industry development.",
    "People are striving for new and better things; keep up with the technological development to sustain a competitive advantage",
    "We need innovation to find solutions that will make future life easier to handle and to overcome problems like climate change",
    "Progress, improvement & to challenge /develop ourselves",
    "So we can make our dogs live longer!",
    "To generate a sustainable competency advantage. To further advance societal and technological progress and possibilities. To benefit the society and overcome challenges (e.g., climate change)",
    "Innovation is relevant for institutions for many reasons: for example it supports creativity and productivity which can lead to a institutions/ firms profit",
    "Innovation is a product or its‘ feature that creates a new value for consumer (both internal or external consumers)"
]

# Joining all responses into a single string
text = " ".join(responses)

# %%
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# Display the generated word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
