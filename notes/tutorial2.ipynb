# %%
import numpy as np
import pandas as pd

np.random.seed(0)
n = 100
height = np.random.normal(160, 10, n)
weight = 50 + 0.5 * height + np.random.normal(0, 5, n)

data = pd.DataFrame({'height': height, 'weight': weight})
data.head()
# Out:
#        height      weight
# 0  177.640523  148.236015
# 1  164.001572  125.261991
# 2  169.787380  128.541265
# 3  182.408932  146.051450
# 4  178.675580  133.472173

# %%
import matplotlib.pyplot as plt

plt.hist(data['height'], bins=20)
plt.xlabel('Height')
plt.ylabel('Frequency')
plt.show()

# %%
plt.scatter(data['height'], data['weight'])
plt.xlabel('Height')
plt.ylabel('Weight')
plt.show()

# %%
data.to_csv('data.csv', index=False)
